# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
currency = pd.read_csv("../data/currency.csv")
currency.head()
# Out:
#    Unnamed: 0       0
# 0  1971-01-04  1.0109
# 1  1971-01-05  1.0102
# 2  1971-01-06  1.0106
# 3  1971-01-07  1.0148
# 4  1971-01-08  1.0154

# %%
currency.columns = ["date", "value"]
currency["date"] = pd.to_datetime(currency["date"])
currency.set_index("date", inplace=True)

# %%
plt.figure(figsize=(10, 6))
currency["value"].plot()
plt.grid()
plt.xlabel("date")
plt.ylabel("Canadian Dollar")
plt.title("Canadian Dollars to U.S. Dollar Spot Exchange Rate")
plt.show()

# %%
currency.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 14535 entries, 1971-01-04 to 2026-09-18
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   13977 non-null  float64
# dtypes: float64(1)
# memory usage: 227.1 KB

# %%
wod = pd.read_csv("../data/wod.csv")
wod.head()
# Out:
#    Unnamed: 0  wod_unique_cast        PLATFORM  \
# 0      442958         22171596  FIXED PLATFORM
# 1      442999         22171621  FIXED PLATFORM
# 2      442987         22171611  FIXED PLATFORM
# 3      442988         22171612  FIXED PLATFORM
# 4      442989         22171612  FIXED PLATFORM
#
#                             INSTITUTE  TEMPERATURE  TEMPERATURE_QC  \
# 0                                 NaN       28.630               0
# 1  US DOC NOAA ERL PMEL (SEATTLE; WA)       29.007               0
# 2                                 NaN       29.020               0
# 3  US DOC NOAA ERL PMEL (SEATTLE; WA)       24.829               0
# 4  US DOC NOAA ERL PMEL (SEATTLE; WA)       24.817               0
#
#   TEMPERATURE_UNIT  DEPTH DEPTH_UNIT                     TIME  LONGITUDE  \
# 0         degree_C    1.0          m  2023-01-01 00:00:00.000      -2.69
# 1         degree_C    1.0          m  2023-01-01 00:00:00.000     165.00
# ...

# %%
wod.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1500 non-null   int64
#  1   wod_unique_cast   1500 non-null   int64
#  2   PLATFORM          222 non-null    str
#  3   INSTITUTE         982 non-null    str
#  4   TEMPERATURE       1500 non-null   float64
#  5   TEMPERATURE_QC    1500 non-null   int64
#  6   TEMPERATURE_UNIT  1500 non-null   str
#  7   DEPTH             1500 non-null   float64
#  8   DEPTH_UNIT        1500 non-null   str
#  9   TIME              1500 non-null   str
#  10  LONGITUDE         1500 non-null   float64
#  11  LATITUDE          1500 non-null   float64
#  12  FEATURE_TYPE      1500 non-null   str
# dtypes: float64(4), int64(3), str(6)
# memory usage: 265.1 KB

# %%
articles = pd.read_json("../data/articles.jsonl", orient="records", lines=True)

# %%
articles.head()
# Out:
#           id  words_cnt                                              title  \
# 0    3867852        441  Increased levels of ethane, a non-invasive, qu...
# 1    4757656        610  Lower levels of damaged protein biomarkers in ...
# 2    4024928        847  Analysis of patient information leaflets (PILs...
# 3      53629       1851  Severe conjunctivochalasis in association with...
# 4  347878447       2543  Vocation and avocation: Leisure activities cor...
#
#    year                                               text
# 0  2010  MEETING ABSTRACT Open Access Increased levels ...
# 1  2012  Summer Meeting hosted by the Irish Section, 16...
# 2  2011  POSTER PRESENTATION Open Access Analysis of pa...
# 3  2012  Whitaker et al. BMC Ophthalmology 2012, 12:47 ...
# 4  2011  Additional File 1 The questionnaire that was s...

# %%
articles["words_cnt"].sum()
# Out:
# np.int64(133320)
